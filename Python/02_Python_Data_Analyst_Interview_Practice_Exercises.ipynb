# %% [markdown]
# <div align="center">
#
# # 🐍 Python Data Analyst Interview Practice
# ### 64 Hands-On Exercises • Write Your Own Solutions
#
# **Target:** Data Analyst / BI Analyst / Product Analyst / Business Analyst
# **Level:** 2–4 years experience
# **Tools:** Python • Pandas • NumPy • Matplotlib • Seaborn • Statistics
#
# </div>
#
# ---
#
# > 🎯 **Practice rule:** Do not look at the solutions while practicing.
# > ✍️ Write your solution directly in the blank code cell under each exercise.
# > 🧠 After solving, explain your approach in the **Interview Notes** cell.
#
# **Source:** Your uploaded *Python Practice Questions for Data Analyst Interviews* document. The source contains 64 practical interview questions organized into six phases. fileciteturn1file1L144-L164

# %% [markdown]
# ## 🚀 How to Use This Notebook
#
# | Step | Action |
# |---|---|
# | 1️⃣ | Read the problem carefully |
# | 2️⃣ | Write your solution in the empty code cell |
# | 3️⃣ | Run and test your code |
# | 4️⃣ | Compare your output with the expected output in the source document |
# | 5️⃣ | Write 1–3 interview notes about your approach |
# | 6️⃣ | Mark your status: ⭐ Solved / 🔁 Retry / ❌ Need Help |
#
# ### Recommended workflow
# **Understand → Code → Test → Explain → Improve**
#
# This notebook intentionally **does not include solutions**, so you can use it as a genuine interview-practice workbook.

# %% [markdown]
# ## 🧰 Practice Environment

# %%
# Run this cell once at the beginning.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional display settings
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

print("Environment ready! 🚀")

# %% [markdown]
# ## 📊 Progress Tracker
#
# Use this quick tracker as you work through the notebook.
#
# - 🟢 Easy: 13 questions
# - 🟡 Medium: 32 questions
# - 🔴 Hard: 19 questions
# - **Total: 64 questions**
#
# **Goal:** Reach a point where you can solve the problems and explain *why* you chose your approach—not just produce code. The source document emphasizes this workflow for real-world Data Analyst interviews. fileciteturn1file3L499-L528

# %% [markdown]
# # ========== Phase 1 — Python Fundamentals ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q01 · 🟢 Easy — Lists and basic calculations
#
# ### 📝 Exercise
# Topic: Lists and basic calculations
# Problem:
# Given the following daily sales values, calculate the total sales and average daily sales using Python.
# Dataset/Input:
# ```python
# sales = [1200, 1500, 1100, 1800, 1600]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q02 · 🟢 Easy — Dictionaries
#
# ### 📝 Exercise
# Topic: Dictionaries
# Problem:
# Given employee salaries, find the employee with the highest salary.
# ```python
# employees = {
#     "Amit": 55000,
#     "Priya": 72000,
#     "Rahul": 68000,
#     "Neha": 61000
# }
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q03 · 🟢 Easy — Conditional statements
#
# ### 📝 Exercise
# Topic: Conditional statements
# Problem:
# Classify customers according to their purchase amount:
# < 1000 → Low
# 1000–5000 → Medium
# > 5000 → High
# ```python
# amounts = [500, 1200, 5500, 3000, 8000]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q04 · 🟢 Easy — Strings
#
# ### 📝 Exercise
# Topic: Strings
# Problem:
# Clean the following customer names by removing extra spaces and converting them to title case.
# ```python
# names = ["  rahul kumar", "PRIYA SHARMA ", " amit singh "]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q05 · 🟢 Easy — Loops
#
# ### 📝 Exercise
# Topic: Loops
# Problem:
# Count how many numbers are greater than 100.
# ```python
# sales = [50, 120, 90, 250, 180, 75]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q06 · 🟢 Easy — List comprehension
#
# ### 📝 Exercise
# Topic: List comprehension
# Problem:
# Create a list containing only sales values greater than 100.
# ```python
# sales = [50, 120, 90, 250, 180, 75]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q07 · 🟢 Easy — Functions
#
# ### 📝 Exercise
# Topic: Functions
# Problem:
# Create a function that calculates conversion rate.
# Formula:
# Conversion Rate = Purchases / Visitors × 100
# For:
# visitors = 10000
# purchases = 450
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q08 · 🟢 Easy — Sets
#
# ### 📝 Exercise
# Topic: Sets
# Problem:
# Find the unique cities in the following dataset.
# ```python
# cities = ["Delhi", "Mumbai", "Delhi", "Noida", "Mumbai", "Pune"]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q09 · 🟢 Easy — Lambda functions
#
# ### 📝 Exercise
# Topic: Lambda functions
# Problem:
# Sort the following employees by salary.
# ```python
# employees = [
#     ("Amit", 60000),
#     ("Priya", 75000),
#     ("Rahul", 55000)
# ]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q10 · 🟢 Easy — Exception handling
#
# ### 📝 Exercise
# Topic: Exception handling
# Problem:
# Write Python code that safely divides two numbers and handles division by zero.
# ```python
# a = 100
# b = 0
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q11 · 🟢 Easy — Dictionaries and counting
#
# ### 📝 Exercise
# Topic: Dictionaries and counting
# Problem:
# Count the number of occurrences of each product.
# ```python
# products = ["Laptop", "Phone", "Laptop", "Tablet", "Phone", "Laptop"]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q12 · 🟡 Medium — Dictionary comprehension
#
# ### 📝 Exercise
# Topic: Dictionary comprehension
# Problem:
# Create a dictionary containing only employees whose salaries are above 60,000.
# ```python
# salary = {
#     "Amit": 55000,
#     "Priya": 72000,
#     "Rahul": 68000,
#     "Neha": 59000
# }
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q13 · 🟡 Medium — File handling
#
# ### 📝 Exercise
# Topic: File handling
# Problem:
# Write Python code to read a CSV file named sales.csv and print the first five lines.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # ========== Phase 2 — NumPy ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q14 · 🟢 Easy — NumPy arrays
#
# ### 📝 Exercise
# Topic: NumPy arrays
# Problem:
# Create a NumPy array from:
# ```python
# sales = [100, 200, 300, 400, 500]
# ```
# Calculate its mean.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q15 · 🟢 Easy — Indexing and slicing
#
# ### 📝 Exercise
# Topic: Indexing and slicing
# Problem:
# Given:
# ```python
# arr = np.array([10, 20, 30, 40, 50])
# ```
# Return the second and fourth elements.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q16 · 🟡 Medium — Reshaping
#
# ### 📝 Exercise
# Topic: Reshaping
# Problem:
# Convert this one-dimensional array into a 2×3 matrix.
# ```python
# arr = np.array([1, 2, 3, 4, 5, 6])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q17 · 🟡 Medium — Boolean filtering
#
# ### 📝 Exercise
# Topic: Boolean filtering
# Problem:
# Find all sales greater than 500.
# ```python
# sales = np.array([200, 700, 450, 900, 300, 800])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q18 · 🟡 Medium — Broadcasting
#
# ### 📝 Exercise
# Topic: Broadcasting
# Problem:
# Increase every salary by 10%.
# ```python
# salary = np.array([50000, 60000, 70000])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q19 · 🟡 Medium — Missing values
#
# ### 📝 Exercise
# Topic: Missing values
# Problem:
# Calculate the average while ignoring NaN values.
# ```python
# arr = np.array([10, 20, np.nan, 40, 50])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q20 · 🟡 Medium — Statistical operations
#
# ### 📝 Exercise
# Topic: Statistical operations
# Problem:
# Calculate mean, median, standard deviation, minimum, and maximum.
# ```python
# sales = np.array([100, 120, 150, 200, 250])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q21 · 🟡 Medium — Axis operations
#
# ### 📝 Exercise
# Topic: Axis operations
# Problem:
# Calculate the total sales for each product.
# ```python
# sales = np.array([
#     [100, 200, 300],
#     [150, 250, 350]
# ])
# ```
# Assume rows represent products and columns represent months.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q22 · 🟡 Medium — Conditional replacement
#
# ### 📝 Exercise
# Topic: Conditional replacement
# Problem:
# Replace all values below 50 with 0.
# ```python
# arr = np.array([20, 60, 40, 80, 30])
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q23 · 🔴 Hard — NumPy statistical analysis
#
# ### 📝 Exercise
# Topic: NumPy statistical analysis
# Problem:
# Given customer spending, calculate the 25th, 50th, and 75th percentiles.
# ```python
# spending = np.array([
#     100, 150, 200, 250, 300,
#     350, 400, 450, 500, 1000
# ])
# ```
# Expected Output: Return the three percentile values.
# Interview Focus:
# Tests percentile calculations and interpretation of customer spending distribution.
# Phase 3 — Pandas
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # ========== Phase 3 — Pandas ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q24 · 🟢 Easy — DataFrame creation
#
# ### 📝 Exercise
# Topic: DataFrame creation
# Problem:
# Create a DataFrame from:
# ```python
# data = {
#     "Name": ["Amit", "Priya", "Rahul"],
#     "Age": [25, 28, 30],
#     "Salary": [50000, 70000, 65000]
# }
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q25 · 🟢 Easy — Selecting columns
#
# ### 📝 Exercise
# Topic: Selecting columns
# Problem:
# From the DataFrame below, select only Customer and Revenue.
# ```python
# df = pd.DataFrame({
#     "Customer": ["A", "B", "C"],
#     "Revenue": [1000, 2000, 1500],
#     "Region": ["North", "South", "West"]
# })
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q26 · 🟢 Easy — Filtering
#
# ### 📝 Exercise
# Topic: Filtering
# Problem:
# Find customers whose revenue is greater than 1500.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q27 · 🟡 Medium — loc and iloc
#
# ### 📝 Exercise
# Topic: loc and iloc
# Problem:
# Explain the difference between loc and iloc, then select the first three rows using iloc.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q28 · 🟡 Medium — Missing values
#
# ### 📝 Exercise
# Topic: Missing values
# Problem:
# Given:
# ```python
# df = pd.DataFrame({
#     "Name": ["A", "B", "C", "D"],
#     "Salary": [50000, np.nan, 70000, np.nan]
# })
# ```
# Replace missing salaries with the median salary.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q29 · 🟡 Medium — Duplicate handling
#
# ### 📝 Exercise
# Topic: Duplicate handling
# Problem:
# Remove duplicate customers.
# ```python
# df = pd.DataFrame({
#     "Customer": ["A", "B", "A", "C", "B"],
#     "Revenue": [100, 200, 100, 300, 200]
# })
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q30 · 🟡 Medium — GroupBy
#
# ### 📝 Exercise
# Topic: GroupBy
# Problem:
# Calculate total revenue by region.
# Customer Region Revenue
# A        North  1000
# B        South  2000
# C        North  1500
# D        South  1200
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q31 · 🟡 Medium — Aggregation
#
# ### 📝 Exercise
# Topic: Aggregation
# Problem:
# Calculate total revenue, average revenue, and number of customers by region.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q32 · 🟡 Medium — transform
#
# ### 📝 Exercise
# Topic: transform
# Problem:
# Calculate each customer’s percentage contribution to their region’s total revenue.
# Interview Focus:
# Tests the difference between agg() and transform().
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q33 · 🟡 Medium — Sorting
#
# ### 📝 Exercise
# Topic: Sorting
# Problem:
# Sort customers from highest to lowest revenue.
# Expected Output: Customers ordered by descending revenue.
# Interview Focus:
# Tests sorting and ranking.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q34 · 🟡 Medium — Merge
#
# ### 📝 Exercise
# Topic: Merge
# Problem:
# Merge customer information with transaction information.
# ```python
# customers
# Customer_ID Name
# 1          Amit
# 2          Priya
# 3          Rahul
#
# orders
# Customer_ID Revenue
# 1          1000
# 2          1500
# 3          700
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q35 · 🟡 Medium — Concatenation
#
# ### 📝 Exercise
# Topic: Concatenation
# Problem:
# Combine January and February sales DataFrames vertically.
# Expected Output:
# A single DataFrame containing both months.
# Interview Focus:
# Tests pd.concat().
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q36 · 🟡 Medium — Pivot table
#
# ### 📝 Exercise
# Topic: Pivot table
# Problem:
# Create a pivot table showing revenue by region and month.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q37 · 🟡 Medium — Date/time
#
# ### 📝 Exercise
# Topic: Date/time
# Problem:
# Convert Order_Date to datetime and extract:
# Year
# Month
# Day
# Month name
# Interview Focus:
# Tests date manipulation used extensively in reporting.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q38 · 🟡 Medium — String operations
#
# ### 📝 Exercise
# Topic: String operations
# Problem:
# Standardize product categories:
# " electronics "
# "Electronics"
# "ELECTRONICS"
# " furniture "
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q39 · 🔴 Hard — Monthly revenue
#
# ### 📝 Exercise
# Topic: Monthly revenue
# Problem:
# Given an orders DataFrame containing Order_Date, Quantity, and Price, calculate monthly revenue.
# Formula:
# Revenue = Quantity × Price
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q40 · 🔴 Hard — Top customers
#
# ### 📝 Exercise
# Topic: Top customers
# Problem:
# Find the top five customers by total lifetime revenue.
# Interview Focus:
# Tests grouping, aggregation, sorting, and business interpretation.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q41 · 🔴 Hard — Rolling average
#
# ### 📝 Exercise
# Topic: Rolling average
# Problem:
# Calculate a 7-day rolling average of daily sales.
# Expected Output: A new column:
# Date        Sales   Rolling_7_Day
# Jan-01      100     ...
# Jan-02      120     ...
# ...
# Interview Focus:
# Tests time-series analysis using Pandas.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q42 · 🔴 Hard — Month-over-month growth
#
# ### 📝 Exercise
# Topic: Month-over-month growth
# Problem:
# Calculate monthly revenue growth percentage.
# Formula:
# MoM Growth =
# (Current Month - Previous Month) / Previous Month × 100
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q43 · 🔴 Hard — Customer retention
#
# ### 📝 Exercise
# Topic: Customer retention
# Problem:
# Given customer purchase dates, calculate how many customers purchased in both January and February.
# Interview Focus:
# Tests set operations, date filtering, and retention logic.
# Phase 4 — Data Analysis & Statistics
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # ========== Phase 4 — Data Analysis & Statistics ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q44 · 🟢 Easy — Mean and median
#
# ### 📝 Exercise
# Topic: Mean and median
# Problem:
# Calculate the mean and median salary.
# ```python
# salary = [30000, 35000, 40000, 45000, 200000]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q45 · 🟢 Easy — Standard deviation
#
# ### 📝 Exercise
# Topic: Standard deviation
# Problem:
# Calculate the standard deviation of:
# ```python
# sales = [100, 110, 105, 95, 500]
# ```
# Then explain what the high standard deviation indicates.
# Interview Focus:
# Tests statistical interpretation rather than just calculation.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q46 · 🟡 Medium — Percentiles
#
# ### 📝 Exercise
# Topic: Percentiles
# Problem:
# A company wants to identify its top 10% highest-spending customers. Which percentile should be used?
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q47 · 🟡 Medium — Correlation
#
# ### 📝 Exercise
# Topic: Correlation
# Problem:
# Calculate the correlation between advertising spend and sales.
# Ad Spend: [10, 20, 30, 40, 50]
# Sales:    [100, 130, 160, 210, 250]
# Interpret the result.
# Interview Focus:
# Tests correlation calculation and interpretation.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q48 · 🟡 Medium — Outliers
#
# ### 📝 Exercise
# Topic: Outliers
# Problem:
# Identify outliers using the IQR method.
# ```python
# sales = [100, 110, 120, 125, 130, 140, 1000]
# ```
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q49 · 🟡 Medium — Distribution
#
# ### 📝 Exercise
# Topic: Distribution
# Problem:
# A company’s salary distribution is strongly right-skewed.
# Which measure should be preferred to represent the typical salary?
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q50 · 🟡 Medium — Sampling
#
# ### 📝 Exercise
# Topic: Sampling
# Problem:
# A company has 1 million customers but can survey only 10,000.
# Explain how you would create a representative sample.
# Interview Focus:
# Tests sampling concepts and bias awareness.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q51 · 🟡 Medium — Confidence interval
#
# ### 📝 Exercise
# Topic: Confidence interval
# Problem:
# A sample has:
# Mean = 50
# Standard Error = 2
# Calculate an approximate 95% confidence interval using:
# Mean ± 1.96 × SE
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q52 · 🟡 Medium — Hypothesis testing
#
# ### 📝 Exercise
# Topic: Hypothesis testing
# Problem:
# A company believes a new feature increases average order value.
# Define:
# Null hypothesis
# Alternative hypothesis
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q53 · 🔴 Hard — A/B testing
#
# ### 📝 Exercise
# Topic: A/B testing
# Problem:
# An e-commerce company tests two checkout designs.
# Control:
# Visitors = 10,000
# Conversions = 500
#
# Treatment:
# Visitors = 10,000
# Conversions = 560
# Calculate conversion rates and determine whether the treatment appears better.
# Interview Focus:
# Tests conversion rate analysis and statistical thinking.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q54 · 🔴 Hard — Statistical significance
#
# ### 📝 Exercise
# Topic: Statistical significance
# Problem:
# An A/B test produces:
# p-value = 0.03
# alpha = 0.05
# Should the null hypothesis be rejected?
# Explain the business implication.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q55 · 🔴 Hard — Correlation vs causation
#
# ### 📝 Exercise
# Topic: Correlation vs causation
# Problem:
# A company discovers:
# Customers who receive more promotional emails
# also generate more revenue.
# Can the company conclude that more emails cause more revenue?
# Explain.
# Interview Focus:
# Tests analytical reasoning and confounding-variable awareness.
# Phase 5 — Data Visualization
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # ========== Phase 5 — Data Visualization ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q56 · 🟢 Easy — Bar chart
#
# ### 📝 Exercise
# Topic: Bar chart
# Problem:
# Create a bar chart showing sales by product.
# Laptop    500000
# Phone     350000
# Tablet    200000
# Expected Output:
# A bar chart comparing product sales.
# Interview Focus:
# Tests basic categorical visualization.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q57 · 🟡 Medium — Line chart
#
# ### 📝 Exercise
# Topic: Line chart
# Problem:
# Create a line chart showing monthly revenue from January to June.
# Expected Output:
# A time-series line chart.
# Interview Focus:
# Tests trend visualization.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q58 · 🟡 Medium — Histogram
#
# ### 📝 Exercise
# Topic: Histogram
# Problem:
# Create a histogram of customer order values.
# Explain what the distribution tells you.
# Interview Focus:
# Tests distribution analysis.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q59 · 🟡 Medium — Box plot
#
# ### 📝 Exercise
# Topic: Box plot
# Problem:
# Create a box plot of employee salaries and identify possible outliers.
# Interview Focus:
# Tests distribution and outlier visualization.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q60 · 🟡 Medium — Scatter plot
#
# ### 📝 Exercise
# Topic: Scatter plot
# Problem:
# Create a scatter plot showing advertising spend versus revenue.
# Add a trend interpretation.
# Interview Focus:
# Tests relationship visualization.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q61 · 🔴 Hard — Heatmap
#
# ### 📝 Exercise
# Topic: Heatmap
# Problem:
# Given a correlation matrix, create a heatmap and identify the strongest relationships.
# Interview Focus:
# Tests correlation analysis and visual interpretation.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q62 · 🔴 Hard — Time-series visualization
#
# ### 📝 Exercise
# Topic: Time-series visualization
# Problem:
# A company has three years of daily sales data.
# Create a visualization that identifies:
# Overall trend
# Monthly seasonality
# Major spikes
# Major drops
# Interview Focus:
# Tests ability to choose an appropriate visualization for time-series analysis.
# Phase 6 — Real-World Data Analyst Problems
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # ========== Phase 6 — Real-World Data Analyst Problems ==========
#
# > **Practice focus:** Work through each question independently. Avoid copying a solution; build the reasoning yourself.

# %% [markdown]
# ## Q63 · 🔴 Hard — E-commerce business analysis
#
# ### 📝 Exercise
# Topic: E-commerce business analysis
# You receive an orders DataFrame:
# Order_ID
# Customer_ID
# Order_Date
# Product
# Category
# Quantity
# Price
# Discount
# Status
# Perform the following:
# Clean missing values.
# Remove duplicate orders.
# Calculate revenue.
# Calculate monthly revenue.
# Find top 5 customers.
# Calculate cancellation rate.
# Calculate average order value.
# Identify the best-performing category.
# Calculate month-over-month growth.
# Provide three business insights.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# ## Q64 · 🔴 Hard — Telecom customer churn analysis
#
# ### 📝 Exercise
# Topic: Telecom customer churn analysis
# You receive:
# Customer_ID
# Tenure
# Plan
# Monthly_Charges
# Data_Usage
# Call_Duration
# Complaints
# Churn
# Perform an end-to-end analysis:
# Clean missing data.
# Identify duplicate customers.
# Calculate overall churn rate.
# Calculate churn by plan.
# Compare average monthly charges between churned and active customers.
# Analyze whether complaints are associated with churn.
# Identify high-risk customer segments.
# Create visualizations.
# Recommend actions to reduce churn.
#
# ### 💡 Your approach
# Write your own solution below. Think about edge cases and how you would explain this in an interview.

# %%
# ✍️ Write your solution here

# %%
# 🎤 Interview Notes
# 1. Approach:
# 2. Why this approach?
# 3. Edge cases / business interpretation:

# %% [markdown]
# # 🧩 Bonus Practice — Rapid-Fire Interview Questions
#
# The source document also includes 10 rapid-fire Python interview questions covering topics such as list vs tuple, `loc` vs `iloc`, `merge()` vs `concat()`, `agg()` vs `transform()`, missing values, duplicates, MoM growth, and Pandas optimization. fileciteturn1file0L19-L38
#
# ### Your answers

# %% [markdown]
# ### ⚡ Rapid-Fire 1
# **What is the difference between a Python list and tuple?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 2
# **What is the difference between loc and iloc?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 3
# **What is the difference between merge() and concat()?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 4
# **When would you use apply()?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 5
# **What is the difference between groupby().agg() and transform()?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 6
# **How do you find missing values in Pandas?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 7
# **How do you remove duplicate rows?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 8
# **How do you calculate month-over-month growth?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 9
# **What is the difference between mean() and median()?**

# %%
# ✍️ Your answer:

# %% [markdown]
# ### ⚡ Rapid-Fire 10
# **How would you optimize a slow Pandas operation?**

# %%
# ✍️ Your answer:

# %% [markdown]
# # 🐞 Bonus Practice — Python Debugging
#
# The source contains 10 debugging exercises designed around common Pandas/Python mistakes, including boolean filtering, incorrect column references, datetime conversion, missing method calls, chained assignment, and division by zero. fileciteturn1file0L39-L130

# %% [markdown]
# ### 🐞 Debug 1
# Fix: `df[df["Sales"] > 1000 and df["Region"] == "North"]`

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 2
# Fix: `df["Revenue"] = df["Quantity"] * "Price"`

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 3
# Why can `df["Date"].dt.month` fail? Write a robust fix.

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 4
# What is missing in `df.groupby("Region")["Revenue"].mean`?

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 5
# Fix the missing method call in `df["Revenue"].fillna(df["Revenue"].mean)`

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 6
# Make `df.sort_values("Revenue")` permanently update the DataFrame in descending order.

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 7
# Fix: `df["Category"].str.lower().strip()`

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 8
# Fix a growth calculation that incorrectly uses `shift` instead of `shift(1)`.

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 9
# Fix the chained assignment: `df.loc[df["Sales"] > 100]["Sales"] = 0`

# %%
# ✍️ Your corrected code:

# %% [markdown]
# ### 🐞 Debug 10
# Prevent infinity when calculating `df["Revenue"] / df["Orders"]` and Orders can be zero.

# %%
# ✍️ Your corrected code:

# %% [markdown]
# # 💼 Bonus Practice — Business Cases
#
# The source includes business cases such as sales decline, customer churn, marketing campaigns, product launch, telecom network experience, employee attrition, e-commerce conversion, subscription revenue, and delivery-time increases. fileciteturn1file7L967-L1056
#
# For each case, practice thinking beyond code:
#
# **Validate data → Compare trends → Segment → Find root cause → Visualize → Recommend action**

# %% [markdown]
# ### 💼 Business Case 1 — Sales Decline
# Monthly sales declined 15% last month. How would you use Python to investigate?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 2 — Customer Churn
# Churn increased from 8% to 12%. Which dimensions would you analyze?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 3 — Marketing Campaign
# A campaign generated 50,000 leads but only 2,000 purchases. Calculate the key KPIs you would investigate.

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 4 — Product Launch
# A new product launched last month. How would you determine whether it is successful?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 5 — Telecom Network
# Customers in one region report poor network experience. What data would you analyze?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 6 — Employee Attrition
# Employee attrition increased significantly. Which dimensions would you analyze?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 7 — E-commerce Conversion
# Website traffic increased 30%, but revenue increased only 5%. How would you investigate?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 8 — Subscription Business
# Monthly recurring revenue is declining. What drivers would you analyze?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# ### 💼 Business Case 9 — Delivery Business
# Average delivery time increased from 30 minutes to 42 minutes. How would you investigate?

# %%
# ✍️ Your analysis / Python approach:

# %% [markdown]
# # 🏁 Final Self-Assessment
#
# The source document provides this scoring rubric:
#
# | Score | Level |
# |---:|---|
# | 0–40% | Beginner |
# | 41–60% | Developing |
# | 61–75% | Intermediate / ready for many Data Analyst interviews |
# | 76–90% | Strong / interview-ready |
# | 91–100% | Excellent |
#
# fileciteturn1file8L1093-L1104
#
# ### My score
# **Solved correctly:** ____ / 64
# **Score:** ____ %
#
# ### Topics I need to revisit
# - [ ] Python fundamentals
# - [ ] NumPy
# - [ ] Pandas / data cleaning
# - [ ] Statistics
# - [ ] A/B testing
# - [ ] Data visualization
# - [ ] Time-series analysis
# - [ ] Business problem solving
# - [ ] SQL + Python integration
#
# ### 🎯 Final Interview Goal
# I can take:
#
# **Messy Dataset → Clean Data → Validate → KPIs → Trends → Statistics → Visualization → Business Insights → Recommendation**

# %% [markdown]
# ---
# <div align="center">
#
# ## 🐍 Keep practicing. Write the code yourself. Explain the business meaning.
#
# **Good analysts don't just calculate numbers — they explain what the numbers mean.**
#
# </div>
